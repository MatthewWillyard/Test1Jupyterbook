# %% [markdown]
# #Math 441

# %% [markdown]
# ##Course Information
#
# * [Syllabus](https://colab.research.google.com/drive/1v7opUYPMPq5pG8pnNM6eh82R_erkC8Ov?usp=drive_link)

# %% [markdown]
# ##Vectors

# %% [markdown]
# ###References
# *  Applied Linear Algebra Chapter 2
# *  Linear Algebra, Data Science, and Machine Learning Chapter 1

# %% [markdown]
# ###Worksheets
#   * [Name](https://link)

# %% [markdown]
# ###Homework
#
# * [Homework 1](https://colab.research.google.com/drive/1qoP-UvGF27UbQscWO__gLfcPDqIWUG7i?usp=sharing)
# * [Homework 2](https://colab.research.google.com/drive/1rq_npAulKDPDyBcbDoUCjKXDTTnnI6HG?usp=drive_link)

# %% [markdown]
# ##Inner products, Orthogonality, and Norms

# %% [markdown]
# ###References
#
# * Applied Linear Algebra Chapter 3 and 4
# * Linear Algebra, Data Science, and Machine Learning Chapter 2

# %% [markdown]
# ###Worksheets

# %% [markdown]
# ###Homework

# %% [markdown]
# ##Matrices

# %% [markdown]
# ###References
# * Applied Linear Algebra Chapters 1
# * Linear Algebra, Data Science, and Machine Learning Chapters 3

# %% [markdown]
# ###Worksheets
#   * [Basic Linear Algebraic Systems](https://colab.research.google.com/drive/1tpoI7j2B2BAOzUUjSz_0whNcGNJAXjLV?usp=drive_link)
#   * [LU Decomposition](https://colab.research.google.com/drive/1ct0s1V-hIRwk8Sw9vgpv8k01Uq_VNz2w?usp=drive_link)

# %% [markdown]
# ##How Matrices Interact with Inner Products and Norms

# %% [markdown]
# ###References
#
# * Applied Linear Algebra Chapters 3 and 4
# * Linear Algebra, Data Science, and Machine Learning Chapter 4

# %% [markdown]
# ##Eigenspaces

# %% [markdown]
# ###References
#
# * Applied Linear Algebra Chapter 8 and 9
#
# * Linear Algebra, Data Science, and Machine Learning Chapter 5
