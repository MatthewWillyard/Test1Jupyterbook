# %% [markdown]
# # Reference Slideshow
#
# This notebook demonstrates all major features.
# Open it as a slideshow to see them in action.
#
# The header and footer on every slide are defined in
# `myst-revealjs.css` in the same directory:
#
# ```css
# .jp-Slideshow-header::after {
#     content: 'jupyterlab-myst-revealjs';
# }
# .jp-Slideshow-footer::after {
#     content: 'Reference Slideshow';
# }
# ```

# %% [markdown]
# # Slide Structure
#
# Each cell has a `slideshow.slide_type` metadata:
#
# - **slide** — new horizontal slide (like this one)
# - **subslide** — vertical slide (press ↓)
# - **fragment** — appears on click
# - **skip** — excluded from slideshow

# %% [markdown]
# This cell has `slide_type: skip` and does not appear in the slideshow.

# %% [markdown]
# ## Subslide
#
# This is a vertical subslide.
#
# Navigate with ↓ and ↑ within a slide group.

# %% [markdown]
# ## Fragments
#
# Content appears incrementally on click:

# %% [markdown]
# **First** — this appears on the first click.

# %% [markdown]
# **Second** — this appears on the next click.

# %% [markdown]
# # MyST Markdown
#
# Rendered by [jupyterlab-myst](https://github.com/jupyter-book/jupyterlab-myst).
#
# :::{note}
# This is a MyST admonition. Admonitions, warnings, tips, and other
# directive types are fully supported.
# :::

# %% [markdown]
# ## Math
#
# Inline math: $e^{i\pi} + 1 = 0$
#
# Display math with a label for cross-referencing:
#
# $$
# \int_{-\infty}^{\infty} e^{-x^2} \, dx = \sqrt{\pi}
# $$ (gaussian-integral)
#
# Hover over {eq}`gaussian-integral` to see the equation tooltip.

# %% [markdown]
# ## Tables and Lists
#
# | Feature | Status |
# |---|---|
# | Admonitions | ✓ |
# | Math | ✓ |
# | Tables | ✓ |
# | Cross-references | ✓ |
#
# :::{warning}
# MyST directives render identically in the slideshow
# and in the notebook view.
# :::

# %% [markdown]
# ## Cross-Slide Equation Reference
#
# This subslide references an equation from a previous slide.
#
# The Gaussian integral {eq}`gaussian-integral` is a fundamental result.
# Hover over the reference to preview it in a tooltip.

# %% [markdown]
# # Code Execution
#
# Press **Shift+Enter** on a focused code cell to execute it.
# Output appears on the slide immediately.

# %%
1 + 1

# %% [markdown]
# ## Rich Output
#
# Plots and other rich outputs are displayed inline.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
plt.plot(x, np.sin(x), label='sin(x)')
plt.plot(x, np.cos(x), label='cos(x)')
plt.legend()
plt.title('Trigonometric Functions')
plt.show()

# %% [markdown]
# # Visibility Tags
#
# Jupyter Book compatible tags control cell visibility.
#
# - `hide-*` — hidden but togglable with `i`/`o` keys
# - `remove-*` — removed from DOM entirely

# %% [markdown]
# The cell below has the `hide-input` tag — only the output is shown.
# Press `i` to reveal the code.

# %%
# This input is hidden by the hide-input tag
print('Only this output is visible on the slide')

# %% [markdown]
# ## hide-output
#
# The cell below has the `hide-output` tag.
# Press `o` to reveal the output.

# %%
print('This output is hidden by the hide-output tag')

# %% [markdown]
# ## remove-input
#
# The cell below has the `remove-input` tag.
# The input is removed from the DOM and cannot be toggled.

# %%
print('Input removed — only output appears')

# %% [markdown]
# # Layout
#
# Use `gridwidth-*` cell tags for side-by-side layout.

# %% [markdown]
# ## Left Column
#
# This cell has the `gridwidth-1-2` tag (50% width).
#
# Place two cells with complementary widths on the same slide.

# %%
# Right column (gridwidth-1-2)
data = {'a': 1, 'b': 2, 'c': 3}
for k, v in data.items():
    print(f'{k}: {v}')

# %% [markdown]
# # Backgrounds
#
# This slide has `slide_background_color: "#1a1a2e"`.
#
# Text color adjusts automatically on dark backgrounds.

# %% [markdown]
# ## Green Background
#
# `slide_background_color: "#2d5016"`
#
# Each slide can have its own background color or image
# via cell metadata.
